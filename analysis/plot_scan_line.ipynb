# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
scan_hist = np.load('scan_hist.npy')

# %%
fig = plt.figure(figsize=(8, 24))
plt.imshow(np.flip(scan_hist, axis=0), extent=[0,100,0,300])
