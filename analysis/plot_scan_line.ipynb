# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
scan_hist = np.load('scan_hist.npy')
row, col = scan_hist.shape
ratio = col / row
fig = plt.figure(figsize=(8, 8*ratio*2))
plt.imshow(np.flip(scan_hist, axis=0), extent=[0,1,0,ratio*2])
